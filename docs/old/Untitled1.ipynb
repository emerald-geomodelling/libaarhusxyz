# %%
import libaarhusxyz
import os.path
import pandas as pd
import libaarhusxyz.normalizer
import downfile
import numpy as np

# %%
a = libaarhusxyz.XYZ("../examples-secret/ags/LCI_Example_MOD_dat.xyz")

# %%
a
# Out:
# ../examples-secret/ags/LCI_Example_MOD_dat.xyz
# --------------------------------
#                                                                       0
# info                  Aarhus Workbench export file. File created: 03...
# wb version                                                      6.7.0.0
# workspace name        C:\Users\Toke.Soeltoft\Downloads\HSM_WS\WS_Kas...
# node name(s)                                           P20130820_F1_I01
# dummy                                                            9999.0
# data unit                                                dB/dt [V/Am^4]
# data type                                                     DTSKYTEM2
# coordinate system                      WGS 84 UTM zone 32N (epsg:32632)
# source                   ../examples-secret/ags/LCI_Example_MOD_dat.xyz
# inversion type                                              Resistivity
# model unit                    Resistivity (Ohm-m) / conductivity (mS/m)
# ...

# %%
a.flightlines
# Out:
#      line_no      utmx       utmy        date          time  record  \
# 0     300101  563458.8  6231699.2  2013-08-20  13:29:00.700       1
# 1     300101  563470.1  6231725.5  2013-08-20  13:29:02.400       2
# 2     300101  563470.1  6231725.5  2013-08-20  13:29:02.400       2
# 3     300101  563481.9  6231750.2  2013-08-20  13:29:04.100       3
# 4     300101  563481.9  6231750.2  2013-08-20  13:29:04.100       3
# ..       ...       ...        ...         ...           ...     ...
# 110   300101  564886.4  6233163.9  2013-08-20  13:31:33.700      57
# 111   300101  564902.5  6233182.8  2013-08-20  13:31:35.400      58
# 112   300101  564902.5  6233182.8  2013-08-20  13:31:35.400      58
# 113   300101  564917.7  6233201.4  2013-08-20  13:31:37.100      59
# 114   300101  564917.7  6233201.4  2013-08-20  13:31:37.100      59
#
#      elevation  altitude_a-priori_[m]  altitude_a-priori_std_[fact]  \
# 0         84.8                 100.40                         1.027
# ...
